# %% [markdown]
# # BEAUTIFUL SOUP AND REQUESTS

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
#html workflow  
'''
1. assign a url to your link
2. Request information from the url using requests.get
3. use Beautiful soup to organise the information from the request by parsing it into html 
4. Use the html organised hieracchies to find elements of your url eg tables, text, headings etc 


'''
# Out:
# '\n1. assign a url to your link\n2. Request information from the url using requests.get\n3. use Beautiful soup to organise the information from the request by parsing it into html \n4. Use the html organised hieracchies to find elements of your url eg tables, text, headings etc \n\n\n'

# %% [markdown]
# ## Hockey Games Website

# %%
url = "https://www.scrapethissite.com/pages/forms/"

# %%
page=requests.get(url)

# %%
soup =BeautifulSoup(page.text, "html")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
#     <meta charset="utf-8"/>
#     <title>Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping</title>
#     <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
#
#     <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#     <meta content="Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components." name="description"/>
#
#     <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
#     <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# ...

# %%
# you can make the soup prettier using prettify 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping
#   </title>
#   <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components." name="description"/>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# ...

# %%
soup.find("div")
# Out:
# <div class="container">
#                 <div class="col-md-12">
#                     <ul class="nav nav-tabs">
#                         <li id="nav-homepage">
#                             <a class="nav-link hidden-sm hidden-xs" href="/">
#                                 <img id="nav-logo" src="/static/images/scraper-icon.png"/>
#                                 Scrape This Site
#                             </a>
#                         </li>
#                         <li id="nav-sandbox">
#                             <a class="nav-link" href="/pages/">
#                                 <i class="glyphicon glyphicon-console hidden-sm hidden-xs"></i>
#                                 Sandbox
#                             </a>
#                         </li>
#                         <li id="nav-lessons">
#                             <a class="nav-link" href="/lessons/">
#                                 <i class="glyphicon glyphicon-education hidden-sm hidden-xs"></i>
# ...

# %%
soup.find_all('p',class_= 'lead')
# Out:
# [<p class="lead">
#                              Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components.
#                              Take a look at how pagination and search elements change the URL as your browse. Build a web scraper that can conduct searches and paginate through the results.
#                          </p>]

# %%
# find all the headings for the table 

soup.find_all("th")
# Out:
# [<th>
#                              Team Name
#                          </th>,
#  <th>
#                              Year
#                          </th>,
#  <th>
#                              Wins
#                          </th>,
#  <th>
#                              Losses
#                          </th>,
#  <th>
#                              OT Losses
#                          </th>,
#  <th>
#                              Win %
#                          </th>,
#  <th>
#                              Goals For (GF)
#                          </th>,
#  <th>
#                              Goals Against (GA)
#                          </th>,
#  <th>
#                              + / -
#                          </th>]

# %%
soup.find('p',class_= 'lead').text.strip()

#text helps us to extract only the text
# strip helps to clean up the text a little bit 
#text doesnt work with findall
# Out:
# 'Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components.\n                            Take a look at how pagination and search elements change the URL as your browse. Build a web scraper that can conduct searches and paginate through the results.'

# %%
hockey_tables = soup.find_all("table")
hockey_tables
# Out:
# [<table class="table">
#                      <tbody><tr>
#                          <th>
#                              Team Name
#                          </th>
#                          <th>
#                              Year
#                          </th>
#                          <th>
#                              Wins
#                          </th>
#                          <th>
#                              Losses
#                          </th>
#                          <th>
#                              OT Losses
#                          </th>
#                          <th>
#                              Win %
#                          </th>
#                          <th>
#                              Goals For (GF)
#                          </th>
#                          <th>
#                              Goals Against (GA)
#                          </th>
#                          <th>
#                              + / -
# ...

# %%
table_headings = soup.find_all("th")

# %%
table_headings_clean= [head.text.strip() for head in table_headings]
table_headings_clean
# Out:
# ['Team Name',
#  'Year',
#  'Wins',
#  'Losses',
#  'OT Losses',
#  'Win %',
#  'Goals For (GF)',
#  'Goals Against (GA)',
#  '+ / -']

# %% [markdown]
# ## Companies Revenue Data on Wikepedia

# %%
url_companies = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue'

page_request = requests.get(url_companies)

soup2 = BeautifulSoup(page_request.text, 'html')

# %%
soup2.find_all("th")
# Out:
# [<th>Rank
#  </th>,
#  <th>Name
#  </th>,
#  <th>Industry
#  </th>,
#  <th>Revenue <br/>(USD millions)
#  </th>,
#  <th>Revenue growth
#  </th>,
#  <th>Employees
#  </th>,
#  <th>Headquarters
#  </th>,
#  <th>Rank
#  </th>,
#  <th>Name
#  </th>,
#  <th>Industry
#  </th>,
#  <th>Revenue <br/>(USD billions)
#  </th>,
#  <th>Employees
#  </th>,
#  <th>Headquarters
#  </th>,
#  <th>Rank
#  </th>,
#  <th>Name
#  </th>,
#  <th>Industry
#  </th>,
#  <th>Profits<br/>(USD millions)
#  </th>]

# %%
soup2.find_all("table")[1]
# Out:
# <table class="wikitable sortable">
# <caption>
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD millions)
# </th>
# <th>Revenue growth
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td><a href="/wiki/Retail" title="Retail">Retail</a>
# </td>
# <td style="text-align:center;">611,289
# </td>
# ...

# %%
soup2.find_all("table", class_ ="wikitable sortable")
# Out:
# [<table class="wikitable sortable">
#  <caption>
#  </caption>
#  <tbody><tr>
#  <th>Rank
#  </th>
#  <th>Name
#  </th>
#  <th>Industry
#  </th>
#  <th>Revenue <br/>(USD millions)
#  </th>
#  <th>Revenue growth
#  </th>
#  <th>Employees
#  </th>
#  <th>Headquarters
#  </th></tr>
#  <tr>
#  <td>1
#  </td>
#  <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
#  </td>
#  <td><a href="/wiki/Retail" title="Retail">Retail</a>
#  </td>
#  <td style="text-align:center;">611,289
#  </td>
# ...

# %%
table = soup2.find_all("table")[1]

# %%
table
# Out:
# <table class="wikitable sortable">
# <caption>
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD millions)
# </th>
# <th>Revenue growth
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td><a href="/wiki/Retail" title="Retail">Retail</a>
# </td>
# <td style="text-align:center;">611,289
# </td>
# ...

# %%
titles = table.find_all("th")

# %%
titles
# Out:
# [<th>Rank
#  </th>,
#  <th>Name
#  </th>,
#  <th>Industry
#  </th>,
#  <th>Revenue <br/>(USD millions)
#  </th>,
#  <th>Revenue growth
#  </th>,
#  <th>Employees
#  </th>,
#  <th>Headquarters
#  </th>]

# %%
#we are going to try and loop through all the titles and extract only the text from each one of them
#strip cleans each of the titles up by removing spaces 

world_table_titles = [title.text.strip() for title in titles]

# %%
world_table_titles
# Out:
# ['Rank',
#  'Name',
#  'Industry',
#  'Revenue (USD millions)',
#  'Revenue growth',
#  'Employees',
#  'Headquarters']

# %%
companies_df = pd.DataFrame(columns=world_table_titles)

# %%
companies_df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue (USD millions), Revenue growth, Employees, Headquarters]
# Index: []

# %%
rows = table.find_all("tr")


for row in rows[1:]: 
        row_data = row.find_all("td")
        individual_data = [data.text.strip() for data in row_data]
        length =len(companies_df)
        companies_df.loc[length]=individual_data 
        #we add this row to the next position in the dataframe

# %%
 companies_df.head()
# Out:
#   Rank                Name                    Industry Revenue (USD millions)  \
# 0    1             Walmart                      Retail                611,289
# 1    2              Amazon  Retail and cloud computing                513,983
# 2    3          ExxonMobil          Petroleum industry                413,680
# 3    4               Apple        Electronics industry                394,328
# 4    5  UnitedHealth Group                  Healthcare                324,162
#
#   Revenue growth  Employees           Headquarters
# 0           6.7%  2,100,000  Bentonville, Arkansas
# 1           9.4%  1,540,000    Seattle, Washington
# 2          44.8%     62,000          Spring, Texas
# 3           7.8%    164,000  Cupertino, California
# 4          12.7%    400,000  Minnetonka, Minnesota

# %%
companies_df.pd_to_csv(r"C:\Users\katri\OneDrive\Desktop\Data practice\Python\File Sorter Project\Companies.csv", index="False")
